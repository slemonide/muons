# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## May 2

# %%
H = [28, 48.16, 25.44, 50.24, 50.23, 37, 21.8, 46, 59.73, 55, 59.26]
Hu = [1, 1, 1, 2, 2, 5, 1, 2, 4, 2, 3]
A = [2, 2.6, 2.6, 2.56, 2.5, 2.57, 2.2, 3.2, 3.7, 3.7, 3.73]
Au = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
L = [9.65, 13, 9, 9.75, 9.5, 9.5, 7.57, 9.5, 10, 10.5, 10]
Lu = [0.5, 0.5, 0.5, 1, 0.5, 0.5, 1, 0.5, 0.5, 0.5, 0.5]
P = [7, 0, 0, 0, 0, 2.5, 2.25, 2.5, 2.5, 3.5, 2.75]
Pu = [0.5, 0, 0, 0, 0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]

labels=['1.3', '1.2', '4.2', '4.1', '4.3', '1.1', '2.1', '3.2', '2.2', '2.3', '3.3']

# %%
len(Pu)
# Out:
# 11

# %%
fig, ax = plt.subplots()

ax.errorbar(H, A, xerr=Hu, yerr=Au, fmt='o')
ax.set_xlabel('Depth (mV)')
ax.set_ylabel('Response (mV)')

for label, x, y in zip(labels, H, A):
    ax.annotate(
        label,
        xy=(x, y), xytext=(50, 30),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
plt.savefig('HA.png')

# %%
fig, ax = plt.subplots()

ax.errorbar(H, L, xerr=Hu, yerr=Lu, fmt='o')
ax.set_xlabel('Depth (mV)')
ax.set_ylabel('Length (ns)')

for label, x, y in zip(labels, H, L):
    ax.annotate(
        label,
        xy=(x, y), xytext=(50, 30),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
plt.savefig('HL.png')

# %%
fig, ax = plt.subplots()

ax.errorbar(A, L, xerr=Hu, yerr=Lu, fmt='o')
ax.set_xlabel('Response (mV)')
ax.set_ylabel('Length (ns)')

for label, x, y in zip(labels, A, L):
    ax.annotate(
        label,
        xy=(x, y), xytext=(50, 30),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
plt.savefig('AL.png')

# %% [markdown]
# Not very interesting:

# %%
fig, ax = plt.subplots()

ax.errorbar(H, P, xerr=Hu, yerr=Pu, fmt='o')
ax.set_xlabel('Depth (mV)')
ax.set_ylabel('Period (ns)')

for label, x, y in zip(labels, H, P):
    ax.annotate(
        label,
        xy=(x, y), xytext=(50, 30),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
plt.savefig('HP.png')

# %% [markdown]
# ## May 3

# %%
labels=['4.2b', '4.2a', '1.2', '2.2', '3.2', '3.3', '1.3', '1.1', '4.1']
H = [25.33, 58, 62, 65, 56, 37.6, 51, 45, 34]
Hu = [1, 5, 4, 6, 2, 3, 3, 3.5, 1]
J = [0.6, 0.5, 0.55, 0.3125, 0.34375, 0.53125, 0.53125, 0.63125, 0.53125]
Ju = [0.2, 0.1, 0.05, 0.04, 0.04, 0.05, 0.05, 0.05, 0.05]
T = [1.5, 1.3, 1.3, 1.57, 1.57, 1.48, 1.43, 1.581, 1.431]
Tu = [0.2, 0.2, 0.2, 0.1, 0.02, 0.1, 0.04, 0.05, 0.1]

# %%
fig, ax = plt.subplots()

ax.errorbar(H, J, xerr=Hu, yerr=Ju, fmt='o')
ax.set_xlabel('Depth (mV)')
ax.set_ylabel('Jitter (ns)')

for label, x, y in zip(labels, H, J):
    ax.annotate(
        label,
        xy=(x, y), xytext=(50, 30),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
plt.savefig('HJ2.png')

# %%
fig, ax = plt.subplots()

ax.errorbar(H, T, xerr=Hu, yerr=Tu, fmt='o')
ax.set_xlabel('Depth (mV)')
ax.set_ylabel('Rise time (ns)')

for label, x, y in zip(labels, H, T):
    ax.annotate(
        label,
        xy=(x, y), xytext=(50, 30),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
plt.savefig('HT2.png')

# %%
fig, ax = plt.subplots()

ax.errorbar(T, J, xerr=Tu, yerr=Ju, fmt='o')
ax.set_xlabel('Rise time (ns)')
ax.set_ylabel('Jitter (ns)')

for label, x, y in zip(labels, T, J):
    ax.annotate(
        label,
        xy=(x, y), xytext=(50, 30),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
plt.savefig('TJ2.png')

# %%
plt.hist(J)
# Out:
# (array([2., 0., 0., 0., 0., 1., 3., 1., 0., 2.]),
#  array([0.3125  , 0.344375, 0.37625 , 0.408125, 0.44    , 0.471875,
#         0.50375 , 0.535625, 0.5675  , 0.599375, 0.63125 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(T)
# Out:
# (array([2., 0., 0., 0., 2., 0., 1., 1., 0., 3.]),
#  array([1.3   , 1.3281, 1.3562, 1.3843, 1.4124, 1.4405, 1.4686, 1.4967,
#         1.5248, 1.5529, 1.581 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# everything seeems to be random
